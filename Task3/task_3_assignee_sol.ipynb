# %% [markdown]
# # Problem Statement

# %% [markdown]
# Preprocessing data is on of the most important task of a ML engineer and it takes about 50-60% of the time while developing any project. Data is collected by scraping the web or by any other means and it is always possible that the dataset is not in the form you will like it to be.
# The dataset provided to you faces the same problem. The csv file open_code_2.csv contains a real world data which has been well structured by us but still requires some preprocessing to be done.
# You have three tasks
# <ul>
# <li>Featurisation of column named <code>size</code>.</li>
# <li>Featurisation of column named <code>installs</code></li>
# <li>Featurisation of column named <code>price</code></li>
# </ul>
# As mentioned earlier you are only allowed to use numpy and pandas for this task.
# Do not edit the cells that are marked as UNIQUE as these cell are provided to help you in completing this assignment.

# %% [markdown]
# # In Colab

# %% [markdown]
# This task does not require you do use gpu so you can work on it on your own cpu but if you want to use this notebook on google colab run the below cell and upload
# <ul>
#     <li>open_code_2.csv</li>
#     <li>check_task3.py</li>
# </ul>

# %%
import os 
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-565e886b-153e-410d-95c2-92441f0145f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-565e886b-153e-410d-95c2-92441f0145f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving check_task3.py to check_task3.py
# Saving open_code_2.csv to open_code_2.csv
# {'check_task3.py': b'import numpy as np\nimport pandas as pd\n\ndef print_success():\n    print("\\x1b\\"Success!!\\"\\x1b")\n\ndef print_fail():\n    print("\\x1b\\"Failure!!\\"\\x1b")\n\ndef is_dataframe(df):\n    return isinstance(df,pd.DataFrame)\n\ndef is_float(df,col):\n    return df.dtypes.to_dict()[col]=="float64"\n\ndef check_float_or_df(df,col):\n    if is_dataframe(df):\n        print_success()\n    else:\n        print_fail()\n        print("The output should be a datframe")\n    if is_float(df,col):\n        print_success()\n    else:\n        print_fail()\n        print("The column element should be float")\n\ndef check_clean_size(df):\n    check_float_or_df(df,\'size\')\n\ndef check_clean_install(df):\n    check_float_or_df(df,\'installs\')\n\ndef check_clean_price(df):\n    check_float_or_df(df,\'price\')',
#  'open_code_2.csv': b'category,reviews,size,installs,price,suitable_for,last_update,latest_ver,popularity\nTOOLS,3988,11M,"1,000,000+",0,Everyone,"December 22, 2015",1.0.5,Low\nFAMILY,12,13M,"1,000+",0,Everyone,"February 3, 2018",1.3.4,Low\nFAMILY,407,306k,"50,000+",0,Mature 17+,"April 11, 2017",1.0,Low\nMEDICAL,19,2.2M,"5,000+",0,Everyone,"May 12, 2018",1.4.15,Low\nGAME,4416,59M,"500,000+",0,Teen,"January 18, 2017",2.1.7,Low\nFAMILY,246,35M,"50,000+",0,Teen,"September 23, 2016",1.0,Low\nSOCIAL,20675,96M,"1,000,000+",0,Teen,"August 2, 2018",4.4.0,Low\nGAME,1976,21M,"100,000+",0,Teen,"March 3, 2018",1.6,Low\nDATING,1093,5.8M,"100,000+",0,Mature 17+,"January 28, 2017",1.6.6,Low\nGAME,2071,36M,"100,000+",0,Everyone,"June 29, 2018",1.0.3,Low\nLIFESTYLE,41,2.9M,"1,000+",$379.99,Everyone,"July 1, 2018",1.0,Low\nSPORTS,1520,6.3M,"50,000+",0,Everyone,"April 17, 2018",3.7,Low\nLIFESTYLE,81,7.7M,"10,000+",0,Everyone,"March 6, 2018",2.0.0.18.03.01,Low\nFAMILY,2714,52M,"500,000+",0,Mature 17+,"November 19, 2017",1.1.8,Low\nNEWS_AND_MAGAZINES,41490,25M,"5,000,000+",0,Teen,"July 24, 2018",4.6.0,Low\nFAMILY,740,20M,"100,000+",0,Teen,"May 24, 2018",3.3.1.41,Low\nGAME,1015,643k,"100,000+",0,Everyone,"November 11, 2015",1.3,Low\nGAME,14823,40M,"1,000,000+",0,Teen,"February 15, 2017",4.0,Low\nPRODUCTIVITY,12,2.2M,"1,000+",0,Everyone,"March 26, 2015",1.0.0.0,Low\nPHOTOGRAPHY,20,4.3M,"1,000+",$2.99,Everyone,"June 18, 2018",1.4.7,Low\nFAMILY,7,2.1M,100+,$3.99,Everyone,"March 23, 2017",1.0,Low\nVIDEO_PLAYERS,78,322k,"10,000+",0,Everyone,"September 19, 2013",1.3,Low\nNEWS_AND_MAGAZINES,124,12M,"10,000+",0,Everyone,"June 29, 2018",4.9.0,Low\nTOOLS,53,3.4M,"1,000+",$1.49,Everyone,"May 19, 2018",1.91,Low\nFAMILY,4,8.0M,"1,000+",0,Everyone,"June 8, 2017",1,Low\nBOOKS_AND_REFERENCE,2539,8.6M,"500,000+",0,Everyone,"July 26, 2018",1.1.6,Low\nHEALTH_AND_FITNESS,32,9.6M,"1,000+",0,Everyone,"May 22, 2018",5.9,Low\nPRODUCTIVITY,617,46M,"100,000+",0,Everyone,"April 17, 2018",1.5.3,Low\nFINANCE,204,29M,"10,000+",0,Everyone,"May 9, 2018",18.1.79,Low\nTRAVEL_AND_LOCAL,69,31M,"10,000+",0,Everyone,"June 11, 2018",3.4.1,Low\nBOOKS_AND_REFERENCE,15,12M,"1,000+",0,Everyone,"November 17, 2017",1.2,Low\nSOCIAL,3640,9.1M,"500,000+",0,Mature 17+,"June 13, 2016",3.1.9,Low\nTOOLS,163997,16M,"10,000,000+",0,Everyone,"August 5, 2018",5.36,Low\nVIDEO_PLAYERS,32,33M,"5,000+",0,Everyone,"July 9, 2018",3.1.0,Low\nNEWS_AND_MAGAZINES,636,1.4M,"100,000+",0,Everyone,"June 8, 2018",1.12.2,Low\nFAMILY,2580,53M,"100,000+",0,Everyone,"July 6, 2018",10,Low\nCOMMUNICATION,10,3.8M,100+,$1.49,Everyone,"May 12, 2018",2.1.4,Low\nFAMILY,606,42M,"50,000+",0,Everyone 10+,"August 16, 2016",1.2,Low\nGAME,33,3.1M,"1,000+",0,Everyone,"December 25, 2017",1.10,Low\nMEDICAL,1838,21M,"100,000+",0,Everyone,"July 2, 2018",2.11.0,Low\nTOOLS,427,9.5M,"100,000+",0,Everyone,"May 4, 2018",1.7.6,Low\nMEDICAL,315,22M,"100,000+",0,Everyone,"October 10, 2017",1.0.02,Low\nDATING,31320,53M,"5,000,000+",0,Mature 17+,"July 30, 2018",6.6.5,Low\nMEDICAL,51,2.4M,"1,000+",$29.99,Everyone,"October 22, 2014",2.0.2,Low\nTOOLS,67,65M,"10,000+",0,Everyone,"June 2, 2017",1.0.8,Low\nLIFESTYLE,377,6.1M,"100,000+",0,Everyone,"March 21, 2017",1.1.4,Low\nBUSINESS,322,1.5M,"50,000+",0,Everyone,"March 28, 2017",2.13,Low\nCOMMUNICATION,497,36M,"100,000+",0,Everyone,"July 17, 2018",8.6.2,Low\nMEDICAL,30,887k,500+,0,Everyone,"May 27, 2016",1.1,Low\nFAMILY,31596,31M,"5,000,000+",0,Teen,"December 23, 2016",1.5,Low\nTOOLS,27,5.0M,"5,000+",0,Everyone,"May 31, 2018",10.1.0,Low\nSHOPPING,4,1.2M,"1,000+",0,Everyone,"July 1, 2018",10.0,Low\nHEALTH_AND_FITNESS,44,49M,"1,000+",0,Everyone,"August 1, 2018",1.0.1,Low\nFAMILY,20843,14M,"1,000,000+",0,Teen,"August 2, 2018",3.3.85.2,Low\nMEDICAL,35,24M,"1,000+",$15.46,Everyone,"May 27, 2015",2.0.3,Low\nHEALTH_AND_FITNESS,3,9.4M,100+,0,Everyone 10+,"June 28, 2018",7.4.8,Low\nFAMILY,79,33M,"5,000+",0,Everyone,"May 27, 2015",1.03,Low\nTOOLS,35,916k,"1,000+",0,Everyone,"October 23, 2017",0.2,Low\nFINANCE,139,3 ...

# %% [markdown]
# # Import Statements

# %%
# UNIQUE 1
# Importing Modules

import numpy as np
import pandas as pd
from check_task3 import *

# %% [markdown]
# # Understanding Data

# %%
# UNIQUE 2
# Running this cell with laod the csv file and put it in the variable df

df = pd.read_csv('./open_code_2.csv')

# %%
# UNIQUE 3
# Running this cell will show you how the dataset looks like 

df.head(10)
# Out:
#   category  reviews  size  ...         last_update latest_ver popularity
# 0    TOOLS     3988   11M  ...   December 22, 2015      1.0.5        Low
# 1   FAMILY       12   13M  ...    February 3, 2018      1.3.4        Low
# 2   FAMILY      407  306k  ...      April 11, 2017        1.0        Low
# 3  MEDICAL       19  2.2M  ...        May 12, 2018     1.4.15        Low
# 4     GAME     4416   59M  ...    January 18, 2017      2.1.7        Low
# 5   FAMILY      246   35M  ...  September 23, 2016        1.0        Low
# 6   SOCIAL    20675   96M  ...      August 2, 2018      4.4.0        Low
# 7     GAME     1976   21M  ...       March 3, 2018        1.6        Low
# 8   DATING     1093  5.8M  ...    January 28, 2017      1.6.6        Low
# 9     GAME     2071   36M  ...       June 29, 2018      1.0.3        Low
#
# [10 rows x 9 columns]

# %%
# We encourage you to do for EDA if you feel necessary because there is no known disadvantages of 
# understanding the dataset better :)

# %% [markdown]
# # Task - 3

# %% [markdown]
# ## Task 3A

# %% [markdown]
# This task requires you to convert the values given in the column <code>size</code> to numerical values first you will check the representation of the size in the column. The file size ending with k denotes that the file is in kb while the file size ending with M denotes that the file is in mb.

# %%
# Write your code to ensure that all the files are in either kb or mb.

check=df['size'].str.contains('M|k')
check.all()
# Out:
# True

# %%
# Write a function that takes in the column 'size' of the dataframe df and then return another dataframe 
# named clean_size_df. In this dataframe the file size which are in mb 
# must be multiplied with 1024 to convert them in kb too. The column element must be float that means
# the terminating unit (k/M) should be removed
# Returned dataframe column name should be same here size

def clean_size(column_df):
    '''
    argument:
        column_df = Dataframeof the column named size
    returns:
        clean_size_df = Dataframe where elements of column_df are changed as specified above
    '''
    column_df=df["size"]
    buffer=[]
    for i in column_df:
        if (('k') in i):
            i = i.rstrip('k')
            i = float(i)
            buffer.append(i)
    
        else:
            i = i.rstrip('M')
            i = float(i)
            i = i*1024
            buffer.append(i)
        
    mySeries = pd.Series(buffer)
    clean_size_df1=df.copy(deep=True)
    clean_size_df1["size"]=mySeries
    return clean_size_df1
clean_size(df['size'])
# Out:
#                 category  reviews  ...      latest_ver popularity
# 0                  TOOLS     3988  ...           1.0.5        Low
# 1                 FAMILY       12  ...           1.3.4        Low
# 2                 FAMILY      407  ...             1.0        Low
# 3                MEDICAL       19  ...          1.4.15        Low
# 4                   GAME     4416  ...           2.1.7        Low
# ...                  ...      ...  ...             ...        ...
# 3012                GAME  3883589  ...          2.21.1       High
# 3013              FAMILY     5898  ...  3.3.8.03082017       High
# 3014              FAMILY       16  ...             1.0       High
# 3015  HEALTH_AND_FITNESS     9612  ...          1.8.12       High
# 3016              SPORTS     1211  ...           1.0.1       High
#
# [3017 rows x 9 columns]

# %% [markdown]
# To let you know if you are making any errors while completing this task we have given helper functions to check your work.
# Success means you have done this part of the task completely and you should proceed to next
# Failure means you messed up some part of your code

# %%
# UNIQUE 4

check_clean_size(clean_size(df['size']))
# Out:
# "Success!!"
# "Success!!"

# %% [markdown]
# ## Task 3B

# %% [markdown]
# In this task you are supposd to featurise the column names <code>installs</code>.
# You are supposed to:
# <ul>
#     <li>Remove the comma(,) from the string</li>
#     <li>Remove the plus sign (+) from the end of the string </li>
#     <li>Convert the string to float</li>
# </ul>

# %%
# Running this code block will show you how installs looks
df['installs']
# Out:
# 0         1,000,000+
# 1             1,000+
# 2            50,000+
# 3             5,000+
# 4           500,000+
#             ...
# 3012    100,000,000+
# 3013        100,000+
# 3014            500+
# 3015        100,000+
# 3016         10,000+
# Name: installs, Length: 3017, dtype: object

# %%
# Write a functions that takes in the column named installs and then returns a dataframe after modifying 
# installs as specified above
# Returned dataframe column name should be same here installs

def clean_install(column_df):
    '''
    parameters:
        df : Dataframe of the column install
    returns:
        final_df : The final dataframe after modifying column_df as specified above
    '''
    final_df = df.copy(deep=True)
    final_df['installs'] = final_df['installs'].str.replace(',', '')
    final_df['installs'] = final_df['installs'].str.rstrip('+')
    final_df['installs'] = final_df['installs'].astype(float)
    
    
    return final_df

# %%
# UNIQUE 5

check_clean_install(clean_install(df['installs']))
# Out:
# "Success!!"
# "Success!!"

# %% [markdown]
# ## Task 3C

# %% [markdown]
# You are required to featurize the column named <code>price</code>
# You are supposed to:
# <ul>
#     <li>Remove the dollor sign if it exists.</li>
#     <li>Convert the string to float. </li>
# </ul>

# %%
# Run this cell to see how the column price looks like
df['price']
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#         ...
# 3012        0
# 3013        0
# 3014    $1.99
# 3015        0
# 3016        0
# Name: price, Length: 3017, dtype: object

# %%
# Write a functions that takes in the column named price and then returns a dataframe after modifying 
# price as specified above
# Returned dataframe column name should be same here price

def clean_price(column_df):
    '''
    parameters:
        df : Dataframe of the column price
    returns:
        final_df : The final dataframe after modifying column_df as specified above
    '''
    
    final_df = df.copy(deep=True)
    final_df['price'] = final_df['price'].str.replace('$', '')
    final_df['price'] = final_df['price'].astype(float)
    return final_df

# %%
#UNIQUE 6

check_clean_price(clean_price(df['price']))
# Out:
# "Success!!"
# "Success!!"

# %% [markdown]
# # Submisson

# %% [markdown]
# Once you are done with the assignment open this notebook in google colab and share the notebook with the people specified below. To avoid plagarism you are adviced to not upload the notebook but just the link with access to only specified persons.
# <table>
#     <tr>
#         <th>Pratyaksh Singh </th>
#         <th>iib2020015@iiita.ac.in </th>
#     </tr>
#     <tr>
#         <th>Himanshu Bhawnani </th>
#         <th>iib2020035@iiita.ac.in </th>
#     </tr>
#     <tr>
#         <th>Parth Soni </th>
#         <th>iec2020132@iiita.ac.in </th>
#     </tr>
#     <tr>
#         <th>Utkarsh </th>
#         <th>iec2020060@iiita.ac.in </th>
#     </tr>
# </table>

# %% [markdown]
# # Enjoy Open Code
